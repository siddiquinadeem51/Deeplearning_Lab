# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Load Dataset
df = pd.read_csv("Lab exp1.csv", sep=';')

# %%
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# Encode categorical columns

for col in df.columns:

    # Encode any non-numeric column
    if df[col].dtype == 'object' or df[col].dtype == 'str':

        le = LabelEncoder()

        df[col] = le.fit_transform(
            df[col].astype(str)
        )

# Verify conversion
print(df.dtypes)
# Out:
# school        int64
# sex           int64
# age           int64
# address       int64
# famsize       int64
# Pstatus       int64
# Medu          int64
# Fedu          int64
# Mjob          int64
# Fjob          int64
# reason        int64
# guardian      int64
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup     int64
# famsup        int64
# paid          int64
# activities    int64
# nursery       int64
# higher        int64
# internet      int64
# romantic      int64
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
# Features and Target

X = df.drop("G3", axis=1)
Y = df["G3"]

# Convert to numpy
X = X.to_numpy(dtype=np.float32)
Y = Y.to_numpy(dtype=np.float32)

# %%
# Normalize features

scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
# Train-Test Split

X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

# %%
# Build Neural Network

model = Sequential([
    Input(shape=(X_train.shape[1],)),

    Dense(128, activation='relu'),

    Dense(64, activation='relu'),

    Dense(32, activation='relu'),

    # Output layer for grade prediction
    Dense(1)
])

# %%
# Compile Model

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,593 (57.00 KB)
#  Trainable params: 14,593 (57.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Model

history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 130.6889 - mae: 10.4392 - val_loss: 116.5515 - val_mae: 10.0449
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 111.2336 - mae: 9.6389 - val_loss: 97.1278 - val_mae: 9.1789
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 91.3996 - mae: 8.7452 - val_loss: 74.5254 - val_mae: 8.0189
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 67.7841 - mae: 7.5088 - val_loss: 48.0756 - val_mae: 6.3202
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42.6153 - mae: 5.8003 - val_loss: 24.2774 - val_mae: 4.2578
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.1395 - mae: 4.0151 - val_loss: 13.0387 - val_mae: 2.7934
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.4300 - mae: 2.9170 - val_loss: 12.1470 - val_mae: 2.4467
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.3658 - mae: 2.4883 - val_loss: 10.3341 - val_mae: 2.2475
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0768 - mae: 2.1492 - val_loss: 8.6948 - val_mae: 2.1878
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5797 - mae: 2.0687 - val_loss: 7.9676 - val_mae: 2.1582
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7361 - mae: 1.9488 - val_loss: 7.4583 - val_mae: 2.0502
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0320 - mae: 1.8058 - val_loss: 7.2082 - val_mae: 1.9685
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5172 - mae: 1.7294 - val_loss: 6.8443 - val_mae: 1.9077
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1300 - mae: 1.6745 - val_loss: 6.5325 - val_mae: 1.8759
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7654 - mae: 1.6209 - val_loss: 6.3650 - val_mae: 1.8521
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4648 - mae: 1.5709 - val_loss: 6.3434 - val_mae: 1.8330
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1890 - mae: 1.5245 - val_loss: 6.1508 - val_mae: 1.8205
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9147 - mae: 1.4850 - val_loss: 6.0238 - val_mae: 1.8073
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0976 - mae: 0.2232 - val_loss: 4.7202 - val_mae: 1.6372
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0911 - mae: 0.2190 - val_loss: 4.6653 - val_mae: 1.6313
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0849 - mae: 0.2073 - val_loss: 4.6680 - val_mae: 1.6279
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0767 - mae: 0.1965 - val_loss: 4.6709 - val_mae: 1.6293
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0737 - mae: 0.1926 - val_loss: 4.7079 - val_mae: 1.6337
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0656 - mae: 0.1837 - val_loss: 4.6366 - val_mae: 1.6216
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0620 - mae: 0.1748 - val_loss: 4.7007 - val_mae: 1.6319
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0570 - mae: 0.1690 - val_loss: 4.6799 - val_mae: 1.6286
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0542 - mae: 0.1645 - val_loss: 4.6527 - val_mae: 1.6230
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0507 - mae: 0.1587 - val_loss: 4.6988 - val_mae: 1.6284
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0462 - mae: 0.1540 - val_loss: 4.6710 - val_mae: 1.6262
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0417 - mae: 0.1422 - val_loss: 4.6910 - val_mae: 1.6313
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0396 - mae: 0.1375 - val_loss: 4.6860 - val_mae: 1.6269
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0361 - mae: 0.1318 - val_loss: 4.6565 - val_mae: 1.6248
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0352 - mae: 0.1319 - val_loss: 4.6948 - val_mae: 1.6287
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0318 - mae: 0.1253 - val_loss: 4.6487 - val_mae: 1.6212
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0290 - mae: 0.1182 - val_loss: 4.6963 - val_mae: 1.6295
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0268 - mae: 0.1124 - val_loss: 4.6642 - val_mae: 1.6239
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0249 - mae: 0.1083 - val_loss: 4.6812 - val_mae: 1.6264
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0237 - mae: 0.1061 - val_loss: 4.6671 - val_mae: 1.6269
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0225 - mae: 0.1050 - val_loss: 4.7045 - val_mae: 1.6316
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0216 - mae: 0.1034 - val_loss: 4.6324 - val_mae: 1.6150
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0200 - mae: 0.0972 - val_loss: 4.6603 - val_mae: 1.6249
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174 - mae: 0.0896 - val_loss: 4.6900 - val_mae: 1.6272
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0164 - mae: 0.0884 - val_loss: 4.6624 - val_mae: 1.6247
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0151 - mae: 0.0833 - val_loss: 4.6956 - val_mae: 1.6291
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140 - mae: 0.0798 - val_loss: 4.6684 - val_mae: 1.6237
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0128 - mae: 0.0757 - val_loss: 4.7017 - val_mae: 1.6317
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0119 - mae: 0.0726 - val_loss: 4.6744 - val_mae: 1.6252
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - mae: 0.0709 - val_loss: 4.6887 - val_mae: 1.6272
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0103 - mae: 0.0668 - val_loss: 4.6920 - val_mae: 1.6282
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0096 - mae: 0.0650 - val_loss: 4.6855 - val_mae: 1.6273
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0090 - mae: 0.0622 - val_loss: 4.6990 - val_mae: 1.6308
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081 - mae: 0.0589 - val_loss: 4.6817 - val_mae: 1.6268
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - mae: 0.0580 - val_loss: 4.7130 - val_mae: 1.6312
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mae: 0.0546 - val_loss: 4.6908 - val_mae: 1.6278

# %%
# Evaluate

test_loss, test_mae = model.evaluate(
    X_test,
    Y_test
)

print(f"\nTest MAE: {test_mae:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5223 - mae: 1.8648
#
# Test MAE: 1.8648

# %%
# Predict first 5 students

predictions = model.predict(X_test[:5])

for i in range(5):

    predicted_grade = predictions[i][0]

    print(f"\nStudent {i+1}")

    print(f"Actual Grade: {Y_test[i]}")

    print(
        f"Predicted Grade: "
        f"{predicted_grade:.2f}"
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Student 1
# Actual Grade: 10.0
# Predicted Grade: 4.76
#
# Student 2
# Actual Grade: 12.0
# Predicted Grade: 12.13
#
# Student 3
# Actual Grade: 5.0
# Predicted Grade: 2.52
#
# Student 4
# Actual Grade: 10.0
# Predicted Grade: 9.37
#
# Student 5
# Actual Grade: 9.0
# Predicted Grade: 12.41
